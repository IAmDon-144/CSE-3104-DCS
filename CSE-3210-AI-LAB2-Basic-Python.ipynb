# %%
print("Hellow World")
# Out:
# Hellow World

# %%
a = 10
b = 5
c = a+b
print(c)
# Out:
# 15

# %%
a,b = 10,5
print(a+b)
# Out:
# 15

# %%
a,b = 153636,5
print(a+b)
# Out:
# 153641

# %%
print(f"The Value of A = {a} and Value of B ={b}")
# Out:
# The Value of A = 153636 and Value of B =5

# %%
x = int(input("Enter the value of X"))
y = int(input("Enter the value of Y"))
print(f"The Sum of X & Y is = {x+y}")
# Out:
# Enter the value of X 56
# Enter the value of Y 4
# The Sum of X & Y is = 60

# %%
lst1 = [1,"I-am-Don" , "A" , "Atia" , 3.114]

# %%
name = lst1[1]
print(name)
# Out:
# I-am-Don

# %%
lst2 = name.split("-")

# %%
print(lst2)
# Out:
# ['I', 'am', 'Don']

# %%
print(name[::-1])
# Out:
# noD-ma-I

# %%
print(lst1[::-1])
# Out:
# [3.114, 'Atia', 'A', 'I-am-Don', 1]

# %%
num  = input("Input a number to Check Odd or Even")
try:
    if (int(num))%2 == 0:
        print(f"{num} is Even")
    else:
        print(f"{num} is Odd")
except:
    print("You Have Given a Wrong Input")
# Out:
# Input a number to Check Odd or Even 56
# 56 is Even

# %%
for i in range(1,11,2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
lol1 = [[1,2],[3,4]]
lol2 = [[-2,5],[7,0]]
print(lol1[0][1])
# Out:
# 2

# %%
dict1 = {
    "A":1,
    "B":2,
    "C":3
}

# %%
for key, value in dict1.items():
    print(f"{key} = {value}")
# Out:
# A = 1
# B = 2
# C = 3

# %%
lst = ["Anika" , "Awal"]

# %%
lst.append("Atia")

# %%
print(lst)
# Out:
# ['Anika', 'Awal', 'Atia']

# %%
for n in lst:
    print(n)
# Out:
# Anika
# Awal
# Atia

# %%
loll = [[2,4],[3,2]]

# %%
print(loll[0])
# Out:
# [2, 4]

# %%
print(loll[0][1])
# Out:
# 4

# %%
l = [["Awal","Nabil"] ,["Anika"],["Sonia"]]

# %%
print(l[0][0])
# Out:
# Awal
